# %% [markdown]
# SEABORN MODULE

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot([0, 1, 2, 3, 4, 5])  # Creates a histogram
plt.show()  # Displays the plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot([1,2,3,4],kind="kde")
plt.show()
